# %% [markdown]
# <a href="https://colab.research.google.com/github/valixonov04/AI_knowledge/blob/main/Pandas_needed_command_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Pandas bilan ishlash uchun eng kerakli 50 ta Pandas amallari.**##

# %% [markdown]
# **1. Datasetni O'rganish**

# %%
import pandas as pd

# %%
import numpy as  np

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.shape # dataning hajmini ko'rish mumkin.
# Out:
# (3000, 9)

# %%
df.info() # biz data haqida bir qancha eng kerakli malumotlarni ko'rishimiz mumkin .
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.describe()  #bu bizga statistik ma'lumotlar ko'rish uchun kerak bo'ladi.
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.columns #dataning ustunlarning  nomini ko'rish mumkin.
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.dtypes # datnig ustunlarni turlarini tekshirish mumkin.
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# **2. Ustunlar bilan ishlash.**

# %%
df["population"] #Ma'lum bir ustuni olish
# Out:
# 0       1537.0
# 1        809.0
# 2       1484.0
# 3         49.0
# 4        850.0
#          ...
# 2995    1258.0
# 2996    3496.0
# 2997     693.0
# 2998      46.0
# 2999     753.0
# Name: population, Length: 3000, dtype: float64

# %%
df[['total_bedrooms', 'population']] # Bir qancha ustunlarni olish
# Out:
#       total_bedrooms  population
# 0              661.0      1537.0
# 1              310.0       809.0
# 2              507.0      1484.0
# 3               15.0        49.0
# 4              244.0       850.0
# ...              ...         ...
# 2995           642.0      1258.0
# 2996          1082.0      3496.0
# 2997           201.0       693.0
# 2998            14.0        46.0
# 2999           263.0       753.0
#
# [3000 rows x 2 columns]

# %%
df['population'].mean() #Ustuning o'rtacha qiymatini olish.
# Out:
# 1402.7986666666666

# %%
df.population.sum() #Ustuning  sumasini olish.
# Out:
# 4208396.0

# %%
df.latitude.max() #Ustuning max qiymati.
# Out:
# 41.92

# %% [markdown]
# **3. Filtirlash va qidirish.**

# %%
df.latitude[df.latitude > 35] #Filtirlangan qatorlarni olish.
# Out:
# 0       37.37
# 4       36.33
# 5       36.51
# 6       38.63
# 7       35.48
#         ...
# 2987    37.29
# 2988    36.97
# 2989    37.60
# 2992    37.39
# 2997    36.30
# Name: latitude, Length: 1368, dtype: float64

# %%
df[df.population > 3000] #Ma'lumotlari shart asosida qatorlarni tanlash.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19      -122.59     38.01                35.0       8814.0          1307.0
# 24      -117.28     33.28                13.0       6131.0          1040.0
# 28      -118.45     34.07                19.0       4845.0          1609.0
# 33      -118.08     34.55                 5.0      16181.0          2971.0
# 45      -117.24     33.17                 4.0       9998.0          1874.0
# ...         ...       ...                 ...          ...             ...
# 2924    -117.23     32.88                18.0       5566.0          1465.0
# 2926    -118.40     34.28                22.0       3517.0           810.0
# 2936    -119.75     36.87                 3.0      13802.0          2244.0
# 2969    -118.11     34.68                 6.0       7430.0          1184.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[(df.population > 3000) &  (df.total_rooms < 300)] # Bir vahtning o'zida bir qancha shartlari qo'lash.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2321    -121.15     38.69                52.0        240.0            44.0
#
#       population  households  median_income  median_house_value
# 2321      6675.0        29.0         6.1359            225000.0

# %%
df.query("population > 3000 & total_rooms < 300") #Bu juda ham foydali command , bu orqali codelarni qisqa va keskor yozishimiz kerak.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2321    -121.15     38.69                52.0        240.0            44.0
#
#       population  households  median_income  median_house_value
# 2321      6675.0        29.0         6.1359            225000.0

# %% [markdown]
# **4. Null qiymatlar bilan ishlash.**

# %%
df.isnull() # Null qiymatlarni aniqlash.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum() #Har bir ustundagi null qilmaylar soni topish
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dropna() #Bu bizga null qiymatlarni tashlab yuborish.Bizning datamizda null qiymat yo'q.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.fillna("n") #Bu bizga null qiymatni biz istagan n son bilan to'ldirish imkoni beradi.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# **5. Ma'lumotlarni O'zgartirish.**

# %%
df["new_ustun"] = df["total_rooms"]*3 # New ustun qo'shish
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df['population'] = df["population"] / 2  #ustundagi qiymatlarni o'zgartirish
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df.rename(columns={'population': 'Odamlar'}, inplace=True) # ustunlarning nomini o'zgartirish.
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df.drop("new_ustun", axis = 1) # bu orqali ustun va qatorlarni o'chirib tashlash mumkin.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       Odamlar  households  median_income  median_house_value
# ...

# %% [markdown]
# **6. Sortlash.**

# %%
df.sort_values("total_rooms") # ma'lum bir ustunlar bo'yicha tartiblab chiqish.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 641     -121.04     37.67                16.0         19.0            19.0
# 2690    -118.06     34.03                36.0         21.0             7.0
# ...         ...       ...                 ...          ...             ...
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 292     -116.36     33.78                 6.0      24121.0          4522.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
#
# ...

# %%
df.sort_values("total_rooms", ascending = False) # teskali tartiblash. Orqadan oldinga qarab.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
# 292     -116.36     33.78                 6.0      24121.0          4522.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# ...         ...       ...                 ...          ...             ...
# 2690    -118.06     34.03                36.0         21.0             7.0
# 641     -121.04     37.67                16.0         19.0            19.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
#
# ...

# %%
df.sort_index( ascending = False) #index bo'yicha sortlash.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2999    -119.63     34.42                42.0       1765.0           263.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# ...         ...       ...                 ...          ...             ...
# 4       -119.67     36.33                19.0       1241.0           244.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 0       -122.05     37.37                27.0       3885.0           661.0
#
# ...

# %% [markdown]
# **7. Ma'lumotlarni gruhlash**

# %%
df.groupby("total_rooms").mean()#Ustuni gruhlab ortacha qiymatni topish.Moshqa operatorlardan ham foydalanish mumkin (size(),sum(),mean(),max(),min())
# Out:
#              longitude  latitude  housing_median_age  total_bedrooms  Odamlar  \
# total_rooms
# 6.0            -116.95     33.86                 1.0             2.0      4.0
# 16.0           -117.12     32.66                52.0             4.0      4.0
# 18.0           -114.62     33.62                26.0             3.0      2.5
# 19.0           -121.04     37.67                16.0            19.0     83.0
# 21.0           -118.06     34.03                36.0             7.0     10.5
# ...                ...       ...                 ...             ...      ...
# 21988.0        -117.12     33.49                 4.0          4055.0   4412.0
# 23915.0        -117.27     33.15                 4.0          4135.0   5438.5
# 24121.0        -116.36     33.78                 6.0          4522.0   2088.0
# 27870.0        -121.53     38.48                 5.0          5027.0   5967.5
# 30450.0        -117.20     33.58                 2.0          5033.0   4709.5
#
# ...

# %% [markdown]
# **8. Pivot jadvalalar.**

# %%
df.pivot_table(
    values="longitude",
    index = "new_ustun",
    aggfunc='mean'
)
# Out:
#            longitude
# new_ustun
# 18.0         -116.95
# 48.0         -117.12
# 54.0         -114.62
# 57.0         -121.04
# 63.0         -118.06
# ...              ...
# 65964.0      -117.12
# 71745.0      -117.27
# 72363.0      -116.36
# 83610.0      -121.53
# 91350.0      -117.20
#
# [2215 rows x 1 columns]

# %% [markdown]
# **9. Indeklash va kesish.**

# %%
data = df.set_index("total_rooms") #Index Ustuning boshaqa ustun bilan almashtirishi.
data
# Out:
#              longitude  latitude  housing_median_age  total_bedrooms  Odamlar  \
# total_rooms
# 3885.0         -122.05     37.37                27.0           661.0    768.5
# 1510.0         -118.30     34.26                43.0           310.0    404.5
# 3589.0         -117.81     33.78                27.0           507.0    742.0
# 67.0           -118.36     33.82                28.0            15.0     24.5
# 1241.0         -119.67     36.33                19.0           244.0    425.0
# ...                ...       ...                 ...             ...      ...
# 1450.0         -119.86     34.42                23.0           642.0    629.0
# 5257.0         -118.14     34.06                27.0          1082.0   1748.0
# 956.0          -119.70     36.30                10.0           201.0    346.5
# 96.0           -117.12     34.10                40.0            14.0     23.0
# 1765.0         -119.63     34.42                42.0           263.0    376.5
#
# ...

# %%
df.reset_index() # Indexni qayata tiklash.
# Out:
#       index  longitude  latitude  housing_median_age  total_rooms  \
# 0         0    -122.05     37.37                27.0       3885.0
# 1         1    -118.30     34.26                43.0       1510.0
# 2         2    -117.81     33.78                27.0       3589.0
# 3         3    -118.36     33.82                28.0         67.0
# 4         4    -119.67     36.33                19.0       1241.0
# ...     ...        ...       ...                 ...          ...
# 2995   2995    -119.86     34.42                23.0       1450.0
# 2996   2996    -118.14     34.06                27.0       5257.0
# 2997   2997    -119.70     36.30                10.0        956.0
# 2998   2998    -117.12     34.10                40.0         96.0
# 2999   2999    -119.63     34.42                42.0       1765.0
#
#       total_bedrooms  Odamlar  households  median_income  median_house_value  \
# 0              661.0    768.5       606.0         6.6085            344700.0
# ...

# %%
df.loc[0:5,"longitude":"total_bedrooms"] #Qator va ustunlarni kesish.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df.iloc[0:5,1:6] #Qator va ustunlar bo'yicha kesish faqat Index orqali
# Out:
#    latitude  housing_median_age  total_rooms  total_bedrooms  Odamlar
# 0     37.37                27.0       3885.0           661.0    768.5
# 1     34.26                43.0       1510.0           310.0    404.5
# 2     33.78                27.0       3589.0           507.0    742.0
# 3     33.82                28.0         67.0            15.0     24.5
# 4     36.33                19.0       1241.0           244.0    425.0

# %% [markdown]
# **10. Vizualizatsiya uchun tayyorlash.**

# %%
df["total_rooms"].hist() #Ustuni vizualizatsiya qilish
# Out:
# <Axes: >

# %%
df.total_rooms.max()
# Out:
# 30450.0

# %%
df["total_rooms"].plot(kind="line") #Ma'lumotlarni Vizuvalitsa qilish
# Out:
# <Axes: >

# %% [markdown]
# **11. Ma'lumotlarni eksport qilish va import qilish.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Shu singari ko'plab file turlarida bi malumotlarni saqlashimiz mumkin.**

# %%
df.to_csv('df.csv') #Ma'lumotlarni CSV faylga saqlash.

# %% [markdown]
# **Malumotlarni o'qish uchun.**

# %%
pd.read_csv("/content/df.csv") # Ma'lumotni o'qish.
# Out:
#       Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0              0    -122.05     37.37                27.0       3885.0
# 1              1    -118.30     34.26                43.0       1510.0
# 2              2    -117.81     33.78                27.0       3589.0
# 3              3    -118.36     33.82                28.0         67.0
# 4              4    -119.67     36.33                19.0       1241.0
# ...          ...        ...       ...                 ...          ...
# 2995        2995    -119.86     34.42                23.0       1450.0
# 2996        2996    -118.14     34.06                27.0       5257.0
# 2997        2997    -119.70     36.30                10.0        956.0
# 2998        2998    -117.12     34.10                40.0         96.0
# 2999        2999    -119.63     34.42                42.0       1765.0
#
#       total_bedrooms  Odamlar  households  median_income  median_house_value  \
# ...

# %% [markdown]
# **12. Statistik funksiya va boshqa usullar.**

# %% [markdown]
# ***Korrelatsiya* — ikki o‘zgaruvchi orasidagi bog‘liqlikni o‘lchaydi.**
#
# **Qiymati -1 dan 1 gacha bo‘ladi:**
#
# **1: Ijobiy, kuchli bog‘liqlik (bir o‘zgaruvchi ortsa, ikkinchisi ham ortadi).**
#
# **-1: Salbiy, kuchli bog‘liqlik (bir o‘zgaruvchi ortsa, ikkinchisi kamayadi).**
#
# **0: Bog‘liqlik yo‘q (mustaqil o‘zgaruvchilar).**

# %%
df.corr() #Korrelatsiya matritsalarni olish.
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925017           -0.064203     0.049865
# latitude            -0.925017  1.000000           -0.025143    -0.039632
# housing_median_age  -0.064203 -0.025143            1.000000    -0.367850
# total_rooms          0.049865 -0.039632           -0.367850     1.000000
# total_bedrooms       0.070869 -0.068245           -0.323154     0.937749
# Odamlar              0.111572 -0.117318           -0.299888     0.838867
# households           0.051062 -0.068296           -0.305171     0.914116
# median_income       -0.018701 -0.072363           -0.144315     0.221249
# median_house_value  -0.050662 -0.138428            0.091409     0.160427
# new_ustun            0.049865 -0.039632           -0.367850     1.000000
#
#                     total_bedrooms   Odamlar  households  median_income  \
# longitude                 0.070869  0.111572    0.051062      -0.018701
# ...

# %%
df.cov() #Kovaritsiya matritsalarni olish.
# Out:
#                        longitude      latitude  housing_median_age  \
# longitude               3.979771     -3.929984           -1.608112
# latitude               -3.929984      4.535492           -0.672300
# housing_median_age     -1.608112     -0.672300          157.637958
# total_rooms           214.433055   -181.938962        -9955.608036
# total_bedrooms         58.765078    -60.411288        -1686.447113
# Odamlar               114.688402   -128.739672        -1940.108606
# households             37.224178    -53.149936        -1400.131655
# median_income          -0.069188     -0.285796           -3.360256
# median_house_value -11432.762614 -33348.376798       129825.029543
# new_ustun             643.299164   -545.816886       -29866.824107
#
#                      total_rooms  total_bedrooms       Odamlar    households  \
# longitude           2.144331e+02    5.876508e+01  1.146884e+02  3.722418e+01
# ...

# %%
df['total_rooms'].value_counts().head(20) #Ustundagi unique(yagona) qiymatlarni sanash.
# Out:
# total_rooms
# 907.0     5
# 1787.0    5
# 1778.0    5
# 1966.0    5
# 1499.0    4
# 1531.0    4
# 956.0     4
# 1564.0    4
# 1401.0    4
# 2584.0    4
# 2287.0    4
# 2387.0    4
# 2085.0    4
# 2127.0    4
# 2581.0    4
# 1425.0    4
# 2711.0    4
# 2077.0    4
# 1743.0    4
# 1613.0    4
# Name: count, dtype: int64

# %%
df.nunique() #Har bir ustundagi unique qiymatlarni sanashi.
# Out:
# longitude              607
# latitude               587
# housing_median_age      52
# total_rooms           2215
# total_bedrooms        1055
# Odamlar               1802
# households            1026
# median_income         2578
# median_house_value    1784
# new_ustun             2215
# dtype: int64

# %% [markdown]
# **13. Data cleansing.**

# %%
df.replace(0,None) #Ma'lum bir qiymatni boshqasiga almashtirish.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
data_duplicates = df.drop_duplicates() #Dublikatlarni olib tashlash.

# %%
data_duplicates.nunique()
# Out:
# longitude              607
# latitude               587
# housing_median_age      52
# total_rooms           2215
# total_bedrooms        1055
# Odamlar               1802
# households            1026
# median_income         2578
# median_house_value    1784
# new_ustun             2215
# dtype: int64

# %%
df.nunique() #Solishtrib ko'rish oldingi qiymatlar bilan.
# Out:
# longitude              607
# latitude               587
# housing_median_age      52
# total_rooms           2215
# total_bedrooms        1055
# Odamlar               1802
# households            1026
# median_income         2578
# median_house_value    1784
# new_ustun             2215
# dtype: int64

# %%
df["total_rooms"].round(5) #Qiymatlarni yaxlitlash.
# Out:
# 0    3885.0
# 1    1510.0
# 2    3589.0
# 3      67.0
# 4    1241.0
# Name: total_rooms, dtype: float64

# %% [markdown]
# **14. Ma'lumotlarni kesish va birlashtirish**

# %%
pd.concat([df,df]) #Jadvalni birlashtirish
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
pd.merge(df,df, on ="total_rooms" ) #siz bergan ustunlarni birlashtirib tashlaydi.
# Out:
#       longitude_x  latitude_x  housing_median_age_x  total_rooms  \
# 0         -122.05       37.37                  27.0       3885.0
# 1         -122.05       37.37                  27.0       3885.0
# 2         -118.30       34.26                  43.0       1510.0
# 3         -118.30       34.26                  43.0       1510.0
# 4         -117.81       33.78                  27.0       3589.0
# ...           ...         ...                   ...          ...
# 4991      -119.70       36.30                  10.0        956.0
# 4992      -117.12       34.10                  40.0         96.0
# 4993      -117.12       34.10                  40.0         96.0
# 4994      -119.63       34.42                  42.0       1765.0
# 4995      -119.63       34.42                  42.0       1765.0
#
#       total_bedrooms_x  Odamlar_x  households_x  median_income_x  \
# 0                661.0      768.5         606.0           6.6085
# ...

# %%
df.sample(n=5) #Tasodifiy bo'lgan n ta qatorni  chiqarib beradi.
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 172     -118.23     33.90                28.0       1108.0           284.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2729    -118.67     34.28                21.0       4059.0           598.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2279    -122.32     37.96                25.0       1728.0           403.0
#
#       Odamlar  households  median_income  median_house_value  new_ustun
# 172     749.0       289.0         2.4706             88800.0     3324.0
# 2994    258.0       174.0         5.5867            182500.0     2793.0
# 2729   1066.5       634.0         5.6949            235300.0    12177.0
# 2987   1013.5       741.0         5.3294            300300.0    12288.0
# 2279    467.0       412.0         3.3750            133700.0     5184.0

# %%
# help(pd.FunctionName) bu orqali siz pandas funksiyalarini batafsil o'rgana olas.
